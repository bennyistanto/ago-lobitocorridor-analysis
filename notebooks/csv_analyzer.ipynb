# %% [markdown]
# # CSV File Analyzer
#
# **Overview**
#
# This script analyzes large CSV files and generates comprehensive metadata and insights that can be shared with AI platforms (like Claude) for further analysis.
# Features
#
# * Dataset Overview: Rows, columns, memory usage, duplicates
# * Column Information: Data types, missing values, unique counts, statistical summaries
# * Data Quality Metrics: Missing data analysis, completeness scores
# * Statistical Summaries: Descriptive statistics for numeric columns
# * Insights Detection: Identifies ID columns, constant columns, high cardinality, missing data patterns
# * Multiple Output Formats: JSON (machine-readable), TXT (human-readable), Column list

# %%
"""
CSV File Analyzer - Generate comprehensive metadata and insights from large CSV files
"""

import pandas as pd
import numpy as np
from pathlib import Path
import json
from datetime import datetime
from collections import Counter

def analyze_csv(file_path, output_dir=None, sample_size=10):
    """
    Analyze a CSV file and generate comprehensive metadata and insights.
    
    Parameters:
    - file_path: Path to the CSV file
    - output_dir: Directory to save output files (defaults to same dir as CSV)
    - sample_size: Number of sample rows to include in the report
    """
    
    file_path = Path(file_path)
    
    if not file_path.exists():
        print(f"❌ Error: File not found at {file_path}")
        return
    
    if output_dir is None:
        output_dir = file_path.parent
    else:
        output_dir = Path(output_dir)
        output_dir.mkdir(parents=True, exist_ok=True)
    
    print("=" * 80)
    print(f"CSV ANALYZER - {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print("=" * 80)
    print(f"📁 File: {file_path.name}")
    print(f"📊 Size: {file_path.stat().st_size / (1024*1024):.2f} MB")
    print()
    
    # Initialize metadata dictionary
    metadata = {
        "file_info": {
            "filename": file_path.name,
            "file_path": str(file_path),
            "file_size_mb": round(file_path.stat().st_size / (1024*1024), 2),
            "analysis_date": datetime.now().isoformat()
        }
    }
    
    # Read CSV
    print("📖 Reading CSV file...")
    try:
        df = pd.read_csv(file_path, low_memory=False)
        print(f"✅ Successfully loaded {len(df):,} rows × {len(df.columns)} columns\n")
    except Exception as e:
        print(f"❌ Error reading CSV: {e}")
        return
    
    # Basic dataset information
    print("=" * 80)
    print("1. DATASET OVERVIEW")
    print("=" * 80)
    
    metadata["dataset_overview"] = {
        "total_rows": int(len(df)),
        "total_columns": int(len(df.columns)),
        "memory_usage_mb": round(df.memory_usage(deep=True).sum() / (1024*1024), 2),
        "total_cells": int(len(df) * len(df.columns)),
        "duplicate_rows": int(df.duplicated().sum())
    }
    
    for key, value in metadata["dataset_overview"].items():
        print(f"  • {key.replace('_', ' ').title()}: {value:,}")
    
    # Column information
    print("\n" + "=" * 80)
    print("2. COLUMN INFORMATION")
    print("=" * 80)
    
    columns_info = []
    
    for col in df.columns:
        col_info = {
            "name": col,
            "dtype": str(df[col].dtype),
            "non_null_count": int(df[col].count()),
            "null_count": int(df[col].isna().sum()),
            "null_percentage": round(df[col].isna().sum() / len(df) * 100, 2),
            "unique_values": int(df[col].nunique()),
            "unique_percentage": round(df[col].nunique() / len(df) * 100, 2)
        }
        
        # Add data type specific information
        if pd.api.types.is_numeric_dtype(df[col]):
            col_info["min"] = float(df[col].min()) if not df[col].isna().all() else None
            col_info["max"] = float(df[col].max()) if not df[col].isna().all() else None
            col_info["mean"] = float(df[col].mean()) if not df[col].isna().all() else None
            col_info["median"] = float(df[col].median()) if not df[col].isna().all() else None
            col_info["std"] = float(df[col].std()) if not df[col].isna().all() else None
        else:
            # For non-numeric, get top values
            top_values = df[col].value_counts().head(5).to_dict()
            col_info["top_5_values"] = {str(k): int(v) for k, v in top_values.items()}
        
        columns_info.append(col_info)
        
        # Print summary
        print(f"\n  📊 {col}")
        print(f"     Type: {col_info['dtype']}")
        print(f"     Non-null: {col_info['non_null_count']:,} ({100-col_info['null_percentage']:.1f}%)")
        print(f"     Unique: {col_info['unique_values']:,} ({col_info['unique_percentage']:.1f}%)")
        
        if 'mean' in col_info:
            if col_info['min'] is not None:
                print(f"     Range: [{col_info['min']:.2f}, {col_info['max']:.2f}]")
                print(f"     Mean: {col_info['mean']:.2f}, Median: {col_info['median']:.2f}")
            else:
                print(f"     Range: [No data - all null values]")
    
    metadata["columns"] = columns_info
    
    # Data quality summary
    print("\n" + "=" * 80)
    print("3. DATA QUALITY METRICS")
    print("=" * 80)
    
    total_cells = len(df) * len(df.columns)
    total_missing = df.isna().sum().sum()
    
    metadata["data_quality"] = {
        "total_missing_values": int(total_missing),
        "missing_percentage": round(total_missing / total_cells * 100, 2),
        "columns_with_missing": int((df.isna().sum() > 0).sum()),
        "complete_rows": int(df.dropna().shape[0]),
        "complete_rows_percentage": round(df.dropna().shape[0] / len(df) * 100, 2)
    }
    
    print(f"  • Total Missing Values: {total_missing:,} ({metadata['data_quality']['missing_percentage']}%)")
    print(f"  • Columns with Missing Data: {metadata['data_quality']['columns_with_missing']}")
    print(f"  • Complete Rows (no missing): {metadata['data_quality']['complete_rows']:,} ({metadata['data_quality']['complete_rows_percentage']:.1f}%)")
    print(f"  • Duplicate Rows: {metadata['dataset_overview']['duplicate_rows']:,}")
    
    # Column types distribution
    print("\n" + "=" * 80)
    print("4. DATA TYPES DISTRIBUTION")
    print("=" * 80)
    
    dtype_counts = df.dtypes.value_counts().to_dict()
    metadata["data_types"] = {str(k): int(v) for k, v in dtype_counts.items()}
    
    for dtype, count in dtype_counts.items():
        print(f"  • {dtype}: {count} columns")
    
    # Numeric columns statistics
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    if len(numeric_cols) > 0:
        print("\n" + "=" * 80)
        print("5. NUMERIC COLUMNS - STATISTICAL SUMMARY")
        print("=" * 80)
        
        numeric_summary = df[numeric_cols].describe().to_dict()
        # Convert to regular python types, handling NaN values
        metadata["numeric_summary"] = {}
        for col, stats in numeric_summary.items():
            metadata["numeric_summary"][col] = {}
            for k, v in stats.items():
                if pd.isna(v):
                    metadata["numeric_summary"][col][k] = None
                else:
                    metadata["numeric_summary"][col][k] = float(v)
        
        for col in numeric_cols[:5]:  # Show first 5 numeric columns
            print(f"\n  📈 {col}")
            stats = df[col].describe()
            for stat_name, stat_value in stats.items():
                if pd.notna(stat_value):
                    print(f"     {stat_name}: {stat_value:.2f}")
                else:
                    print(f"     {stat_name}: N/A")
    
    # Sample data
    print("\n" + "=" * 80)
    print(f"6. SAMPLE DATA (First {sample_size} rows)")
    print("=" * 80)
    
    sample_data = df.head(sample_size).to_dict('records')
    metadata["sample_data"] = sample_data
    
    print(df.head(sample_size).to_string())
    
    # Potential insights
    print("\n" + "=" * 80)
    print("7. POTENTIAL INSIGHTS")
    print("=" * 80)
    
    insights = []
    
    # Check for ID columns
    potential_ids = [col for col in df.columns if df[col].nunique() == len(df)]
    if potential_ids:
        insight = f"Potential ID columns (100% unique): {', '.join(potential_ids)}"
        insights.append(insight)
        print(f"  🔍 {insight}")
    
    # Check for constant columns
    constant_cols = [col for col in df.columns if df[col].nunique() == 1]
    if constant_cols:
        insight = f"Constant columns (only 1 unique value): {', '.join(constant_cols)}"
        insights.append(insight)
        print(f"  🔍 {insight}")
    
    # Check for high cardinality columns
    high_cardinality = [col for col in df.columns 
                       if df[col].nunique() > len(df) * 0.9 and col not in potential_ids]
    if high_cardinality:
        insight = f"High cardinality columns (>90% unique): {', '.join(high_cardinality)}"
        insights.append(insight)
        print(f"  🔍 {insight}")
    
    # Check for columns with high missing rate
    high_missing = [col for col in df.columns if df[col].isna().sum() / len(df) > 0.5]
    if high_missing:
        insight = f"Columns with >50% missing data: {', '.join(high_missing)}"
        insights.append(insight)
        print(f"  🔍 {insight}")
    
    # Check for numeric columns with zeros
    for col in numeric_cols:
        zero_pct = (df[col] == 0).sum() / len(df) * 100
        if zero_pct > 50:
            insight = f"{col} has {zero_pct:.1f}% zero values"
            insights.append(insight)
            print(f"  🔍 {insight}")
    
    metadata["insights"] = insights
    
    # Save outputs
    print("\n" + "=" * 80)
    print("8. SAVING OUTPUTS")
    print("=" * 80)
    
    # Save JSON metadata
    json_output = output_dir / f"{file_path.stem}_metadata.json"
    with open(json_output, 'w', encoding='utf-8') as f:
        json.dump(metadata, f, indent=2, ensure_ascii=False)
    print(f"  ✅ JSON metadata saved: {json_output}")
    
    # Save text report
    txt_output = output_dir / f"{file_path.stem}_report.txt"
    with open(txt_output, 'w', encoding='utf-8') as f:
        f.write("=" * 80 + "\n")
        f.write(f"CSV ANALYSIS REPORT - {file_path.name}\n")
        f.write(f"Generated: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
        f.write("=" * 80 + "\n\n")
        
        f.write("DATASET OVERVIEW\n")
        f.write("-" * 80 + "\n")
        for key, value in metadata["dataset_overview"].items():
            f.write(f"{key.replace('_', ' ').title()}: {value:,}\n")
        
        f.write("\n\nCOLUMN SUMMARY\n")
        f.write("-" * 80 + "\n")
        for col_info in columns_info:
            f.write(f"\n{col_info['name']}\n")
            f.write(f"  Type: {col_info['dtype']}\n")
            f.write(f"  Non-null: {col_info['non_null_count']:,} ({100-col_info['null_percentage']:.1f}%)\n")
            f.write(f"  Unique: {col_info['unique_values']:,} ({col_info['unique_percentage']:.1f}%)\n")
        
        f.write("\n\nINSIGHTS\n")
        f.write("-" * 80 + "\n")
        for insight in insights:
            f.write(f"• {insight}\n")
    
    print(f"  ✅ Text report saved: {txt_output}")
    
    # Save column list
    col_list_output = output_dir / f"{file_path.stem}_columns.txt"
    with open(col_list_output, 'w', encoding='utf-8') as f:
        f.write("COLUMN LIST\n")
        f.write("=" * 80 + "\n\n")
        for i, col in enumerate(df.columns, 1):
            f.write(f"{i}. {col} ({df[col].dtype})\n")
    print(f"  ✅ Column list saved: {col_list_output}")
    
    print("\n" + "=" * 80)
    print("✨ ANALYSIS COMPLETE!")
    print("=" * 80)
    print(f"\nOutput files saved to: {output_dir}")
    print("\nYou can now share the generated files with Claude AI for further analysis!")
    
    return metadata


if __name__ == "__main__":
    # Configuration
    PROJECT_ROOT = Path("/mnt/c/Users/benny/OneDrive/Documents/Github/ago-lobitocorridor-analysis")
    CSV_FILE = PROJECT_ROOT / "outputs/tables/huambo_municipality_profiles.csv"
    OUTPUT_DIR = PROJECT_ROOT / "outputs/analysis_summary"  # Will save summary files here
    
    # Run analysis
    analyze_csv(
        file_path=CSV_FILE,
        output_dir=OUTPUT_DIR,
        sample_size=10  # Number of sample rows to include
    )
# Out:
# ================================================================================
# CSV ANALYZER - 2025-11-01 10:14:11
# ================================================================================
# 📁 File: huambo_municipality_profiles.csv
# 📊 Size: 142.87 MB
#
# 📖 Reading CSV file...
# ✅ Successfully loaded 904,604 rows × 104 columns
#
# ================================================================================
# 1. DATASET OVERVIEW
# ================================================================================
#   • Total Rows: 904,604
#   • Total Columns: 104
#   • Memory Usage Mb: 845.11
#   • Total Cells: 94,078,816
#   • Duplicate Rows: 904,561
#
# ================================================================================
# 2. COLUMN INFORMATION
# ================================================================================
#
#   📊 ADM2CD_c
#      Type: object
#      Non-null: 904,604 (100.0%)
#      Unique: 39 (0.0%)
#
#   📊 NAM_1
#      Type: object
#      Non-null: 904,604 (100.0%)
#      Unique: 5 (0.0%)
#
#   📊 NAM_2
#      Type: object
#      Non-null: 904,604 (100.0%)
#      Unique: 39 (0.0%)
#
#   📊 poverty__rivers
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__streams
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__lakes
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__lagoons
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__wells
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__telephone
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__internet
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__newspaper
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__radio
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__television
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__none
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__electricity
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__water_storage
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__veterinarians
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__banking
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__mech_agri_equip
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__agri_schools
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__primary_schools
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__field_schools
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__health_units
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__agri_stock
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__went_without_food
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__unable_eat_healthy
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__few_types_of_food
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__skipped_meal
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__ate_less_than_needed
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__ran_out_of_food
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__hungry_did_not_eat
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__without_food_all_day
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__food_insec_scale
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__difficult_access_to_village
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__insufficient_transport
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__lack_conservation_infra
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__high_transport_cost
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__lack_transport_means
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__other
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__poverty_rural
#      Type: float64
#      Non-null: 904,604 (100.0%)
#      Unique: 37 (0.0%)
#      Range: [0.00, 0.77]
#      Mean: 0.62, Median: 0.65
#
#   📊 poverty__poverty_urban
#      Type: float64
#      Non-null: 904,604 (100.0%)
#      Unique: 35 (0.0%)
#      Range: [0.00, 0.62]
#      Mean: 0.42, Median: 0.42
#
#   📊 poverty__poverty_total
#      Type: float64
#      Non-null: 904,604 (100.0%)
#      Unique: 36 (0.0%)
#      Range: [0.00, 0.74]
#      Mean: 0.55, Median: 0.60
#
#   📊 poverty__diff_access_land
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__unavailable_agri_land
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__diff_access_water
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__rural_exodus
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__diff_dispose_products
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__lack_rain
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__lack_agri_equipment
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__lack_tech_assist
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__lack_manpower
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__diff_access_credit
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 poverty__avg_hours_to_market_financial
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__rivers
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__streams
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__lakes
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__lagoons
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__wells
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__telephone
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__internet
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__newspaper
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__radio
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__television
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__none
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__electricity
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__water_storage
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__veterinarians
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__banking
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__mech_agri_equip
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__agri_schools
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__primary_schools
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__field_schools
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__health_units
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__agri_stock
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__went_without_food
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__unable_eat_healthy
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__few_types_of_food
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__skipped_meal
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__ate_less_than_needed
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__ran_out_of_food
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__hungry_did_not_eat
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__without_food_all_day
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__food_insec_scale
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__difficult_access_to_village
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__insufficient_transport
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__lack_conservation_infra
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__high_transport_cost
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__lack_transport_means
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__other
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__poverty_rural
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__poverty_urban
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__poverty_total
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__diff_access_land
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__unavailable_agri_land
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__diff_access_water
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__rural_exodus
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__diff_dispose_products
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__lack_rain
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__lack_agri_equipment
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__lack_tech_assist
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__lack_manpower
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__diff_access_credit
#      Type: float64
#      Non-null: 0 (0.0%)
#      Unique: 0 (0.0%)
#      Range: [No data - all null values]
#
#   📊 traveltime__avg_hours_to_market_financial
#      Type: float64
#      Non-null: 904,604 (100.0%)
#      Unique: 38 (0.0%)
#      Range: [0.00, 484.49]
#      Mean: 136.84, Median: 105.84
#
#   📊 poverty_quintile
#      Type: int64
#      Non-null: 904,604 (100.0%)
#      Unique: 5 (0.0%)
#      Range: [1.00, 5.00]
#      Mean: 3.00, Median: 3.00
#
# ================================================================================
# 3. DATA QUALITY METRICS
# ================================================================================
#   • Total Missing Values: 86,841,984 (92.31%)
#   • Columns with Missing Data: 96
#   • Complete Rows (no missing): 0 (0.0%)
#   • Duplicate Rows: 904,561
#
# ================================================================================
# 4. DATA TYPES DISTRIBUTION
# ================================================================================
#   • float64: 100 columns
#   • object: 3 columns
#   • int64: 1 columns
#
# ================================================================================
# 5. NUMERIC COLUMNS - STATISTICAL SUMMARY
# ================================================================================
#
#   📈 poverty__rivers
#      count: 0.00
#      mean: N/A
#      std: N/A
#      min: N/A
#      25%: N/A
#      50%: N/A
#      75%: N/A
#      max: N/A
#
#   📈 poverty__streams
#      count: 0.00
#      mean: N/A
#      std: N/A
#      min: N/A
#      25%: N/A
#      50%: N/A
#      75%: N/A
#      max: N/A
#
#   📈 poverty__lakes
#      count: 0.00
#      mean: N/A
#      std: N/A
#      min: N/A
#      25%: N/A
#      50%: N/A
#      75%: N/A
#      max: N/A
#
#   📈 poverty__lagoons
#      count: 0.00
#      mean: N/A
#      std: N/A
#      min: N/A
#      25%: N/A
#      50%: N/A
#      75%: N/A
#      max: N/A
#
#   📈 poverty__wells
#      count: 0.00
#      mean: N/A
#      std: N/A
#      min: N/A
#      25%: N/A
#      50%: N/A
#      75%: N/A
#      max: N/A
#
# ================================================================================
# 6. SAMPLE DATA (First 10 rows)
# ================================================================================
#     ADM2CD_c     NAM_1       NAM_2  poverty__rivers  poverty__streams  poverty__lakes  poverty__lagoons  poverty__wells  poverty__telephone  poverty__internet  poverty__newspaper  poverty__radio  poverty__television  poverty__none  poverty__electricity  poverty__water_storage  poverty__veterinarians  poverty__banking  poverty__mech_agri_equip  poverty__agri_schools  poverty__primary_schools  poverty__field_schools  poverty__health_units  poverty__agri_stock  poverty__went_without_food  poverty__unable_eat_healthy  poverty__few_types_of_food  poverty__skipped_meal  poverty__ate_less_than_needed  poverty__ran_out_of_food  poverty__hungry_did_not_eat  poverty__without_food_all_day  poverty__food_insec_scale  poverty__difficult_access_to_village  poverty__insufficient_transport  poverty__lack_conservation_infra  poverty__high_transport_cost  poverty__lack_transport_means  poverty__other  poverty__poverty_rural  poverty__poverty_urban  poverty__poverty_total  poverty__diff_access_land  poverty__unavailable_agri_land  poverty__diff_access_water  poverty__rural_exodus  poverty__diff_dispose_products  poverty__lack_rain  poverty__lack_agri_equipment  poverty__lack_tech_assist  poverty__lack_manpower  poverty__diff_access_credit  poverty__avg_hours_to_market_financial  traveltime__rivers  traveltime__streams  traveltime__lakes  traveltime__lagoons  traveltime__wells  traveltime__telephone  traveltime__internet  traveltime__newspaper  traveltime__radio  traveltime__television  traveltime__none  traveltime__electricity  traveltime__water_storage  traveltime__veterinarians  traveltime__banking  traveltime__mech_agri_equip  traveltime__agri_schools  traveltime__primary_schools  traveltime__field_schools  traveltime__health_units  traveltime__agri_stock  traveltime__went_without_food  traveltime__unable_eat_healthy  traveltime__few_types_of_food  traveltime__skipped_meal  traveltime__ate_less_than_needed  traveltime__ran_out_of_food  traveltime__hungry_did_not_eat  traveltime__without_food_all_day  traveltime__food_insec_scale  traveltime__difficult_access_to_village  traveltime__insufficient_transport  traveltime__lack_conservation_infra  traveltime__high_transport_cost  traveltime__lack_transport_means  traveltime__other  traveltime__poverty_rural  traveltime__poverty_urban  traveltime__poverty_total  traveltime__diff_access_land  traveltime__unavailable_agri_land  traveltime__diff_access_water  traveltime__rural_exodus  traveltime__diff_dispose_products  traveltime__lack_rain  traveltime__lack_agri_equipment  traveltime__lack_tech_assist  traveltime__lack_manpower  traveltime__diff_access_credit  traveltime__avg_hours_to_market_financial  poverty_quintile
# 0  AGO002001  Benguela  Baia Farta              NaN               NaN             NaN               NaN             NaN                 NaN                NaN                 NaN             NaN                  NaN            NaN                   NaN                     NaN                     NaN               NaN                       NaN                    NaN                       NaN                     NaN                    NaN                  NaN                         NaN                          NaN                         NaN                    NaN                            NaN                       NaN                          NaN                            NaN                        NaN                                   NaN                              NaN                               NaN                           NaN                            NaN             NaN                   0.442                   0.258                   0.318                        NaN                             NaN                         NaN                    NaN                             NaN                 NaN                           NaN                        NaN                     NaN                          NaN                                     NaN                 NaN                  NaN                NaN                  NaN                NaN                    NaN                   NaN                    NaN                NaN                     NaN               NaN                      NaN                        NaN                        NaN                  NaN                          NaN                       NaN                          NaN                        NaN                       NaN                     NaN                            NaN                             NaN                            NaN                       NaN                               NaN                          NaN                             NaN                               NaN                           NaN                                      NaN                                 NaN                                  NaN                              NaN                               NaN                NaN                        NaN                        NaN                        NaN                           NaN                                NaN                            NaN                       NaN                                NaN                    NaN                              NaN                           NaN                        NaN                             NaN                                  75.299117                 1
# 1  AGO002001  Benguela  Baia Farta              NaN               NaN             NaN               NaN             NaN                 NaN                NaN                 NaN             NaN                  NaN            NaN                   NaN                     NaN                     NaN               NaN                       NaN                    NaN                       NaN                     NaN                    NaN                  NaN                         NaN                          NaN                         NaN                    NaN                            NaN                       NaN                          NaN                            NaN                        NaN                                   NaN                              NaN                               NaN                           NaN                            NaN             NaN                   0.442                   0.258                   0.318                        NaN                             NaN                         NaN                    NaN                             NaN                 NaN                           NaN                        NaN                     NaN                          NaN                                     NaN                 NaN                  NaN                NaN                  NaN                NaN                    NaN                   NaN                    NaN                NaN                     NaN               NaN                      NaN                        NaN                        NaN                  NaN                          NaN                       NaN                          NaN                        NaN                       NaN                     NaN                            NaN                             NaN                            NaN                       NaN                               NaN                          NaN                             NaN                               NaN                           NaN                                      NaN                                 NaN                                  NaN                              NaN                               NaN                NaN                        NaN                        NaN                        NaN                           NaN                                NaN                            NaN                       NaN                                NaN                    NaN                              NaN                           NaN                        NaN                             NaN                                  75.299117                 1
# 2  AGO002001  Benguela  Baia Farta              NaN               NaN             NaN               NaN             NaN                 NaN                NaN                 NaN             NaN                  NaN            NaN                   NaN                     NaN                     NaN               NaN                       NaN                    NaN                       NaN                     NaN                    NaN                  NaN                         NaN                          NaN                         NaN                    NaN                            NaN                       NaN                          NaN                            NaN                        NaN                                   NaN                              NaN                               NaN                           NaN                            NaN             NaN                   0.442                   0.258                   0.318                        NaN                             NaN                         NaN                    NaN                             NaN                 NaN                           NaN                        NaN                     NaN                          NaN                                     NaN                 NaN                  NaN                NaN                  NaN                NaN                    NaN                   NaN                    NaN                NaN                     NaN               NaN                      NaN                        NaN                        NaN                  NaN                          NaN                       NaN                          NaN                        NaN                       NaN                     NaN                            NaN                             NaN                            NaN                       NaN                               NaN                          NaN                             NaN                               NaN                           NaN                                      NaN                                 NaN                                  NaN                              NaN                               NaN                NaN                        NaN                        NaN                        NaN                           NaN                                NaN                            NaN                       NaN                                NaN                    NaN                              NaN                           NaN                        NaN                             NaN                                  75.299117                 1
# 3  AGO002001  Benguela  Baia Farta              NaN               NaN             NaN               NaN             NaN                 NaN                NaN                 NaN             NaN                  NaN            NaN                   NaN                     NaN                     NaN               NaN                       NaN                    NaN                       NaN                     NaN                    NaN                  NaN                         NaN                          NaN                         NaN                    NaN                            NaN                       NaN                          NaN                            NaN                        NaN                                   NaN                              NaN                               NaN                           NaN                            NaN             NaN                   0.442                   0.258                   0.318                        NaN                             NaN                         NaN                    NaN                             NaN                 NaN                           NaN                        NaN                     NaN                          NaN                                     NaN                 NaN                  NaN                NaN                  NaN                NaN                    NaN                   NaN                    NaN                NaN                     NaN               NaN                      NaN                        NaN                        NaN                  NaN                          NaN                       NaN                          NaN                        NaN                       NaN                     NaN                            NaN                             NaN                            NaN                       NaN                               NaN                          NaN                             NaN                               NaN                           NaN                                      NaN                                 NaN                                  NaN                              NaN                               NaN                NaN                        NaN                        NaN                        NaN                           NaN                                NaN                            NaN                       NaN                                NaN                    NaN                              NaN                           NaN                        NaN                             NaN                                  75.299117                 1
# 4  AGO002001  Benguela  Baia Farta              NaN               NaN             NaN               NaN             NaN                 NaN                NaN                 NaN             NaN                  NaN            NaN                   NaN                     NaN                     NaN               NaN                       NaN                    NaN                       NaN                     NaN                    NaN                  NaN                         NaN                          NaN                         NaN                    NaN                            NaN                       NaN                          NaN                            NaN                        NaN                                   NaN                              NaN                               NaN                           NaN                            NaN             NaN                   0.442                   0.258                   0.318                        NaN                             NaN                         NaN                    NaN                             NaN                 NaN                           NaN                        NaN                     NaN                          NaN                                     NaN                 NaN                  NaN                NaN                  NaN                NaN                    NaN                   NaN                    NaN                NaN                     NaN               NaN                      NaN                        NaN                        NaN                  NaN                          NaN                       NaN                          NaN                        NaN                       NaN                     NaN                            NaN                             NaN                            NaN                       NaN                               NaN                          NaN                             NaN                               NaN                           NaN                                      NaN                                 NaN                                  NaN                              NaN                               NaN                NaN                        NaN                        NaN                        NaN                           NaN                                NaN                            NaN                       NaN                                NaN                    NaN                              NaN                           NaN                        NaN                             NaN                                  75.299117                 1
# 5  AGO002001  Benguela  Baia Farta              NaN               NaN             NaN               NaN             NaN                 NaN                NaN                 NaN             NaN                  NaN            NaN                   NaN                     NaN                     NaN               NaN                       NaN                    NaN                       NaN                     NaN                    NaN                  NaN                         NaN                          NaN                         NaN                    NaN                            NaN                       NaN                          NaN                            NaN                        NaN                                   NaN                              NaN                               NaN                           NaN                            NaN             NaN                   0.442                   0.258                   0.318                        NaN                             NaN                         NaN                    NaN                             NaN                 NaN                           NaN                        NaN                     NaN                          NaN                                     NaN                 NaN                  NaN                NaN                  NaN                NaN                    NaN                   NaN                    NaN                NaN                     NaN               NaN                      NaN                        NaN                        NaN                  NaN                          NaN                       NaN                          NaN                        NaN                       NaN                     NaN                            NaN                             NaN                            NaN                       NaN                               NaN                          NaN                             NaN                               NaN                           NaN                                      NaN                                 NaN                                  NaN                              NaN                               NaN                NaN                        NaN                        NaN                        NaN                           NaN                                NaN                            NaN                       NaN                                NaN                    NaN                              NaN                           NaN                        NaN                             NaN                                  75.299117                 1
# 6  AGO002001  Benguela  Baia Farta              NaN               NaN             NaN               NaN             NaN                 NaN                NaN                 NaN             NaN                  NaN            NaN                   NaN                     NaN                     NaN               NaN                       NaN                    NaN                       NaN                     NaN                    NaN                  NaN                         NaN                          NaN                         NaN                    NaN                            NaN                       NaN                          NaN                            NaN                        NaN                                   NaN                              NaN                               NaN                           NaN                            NaN             NaN                   0.442                   0.258                   0.318                        NaN                             NaN                         NaN                    NaN                             NaN                 NaN                           NaN                        NaN                     NaN                          NaN                                     NaN                 NaN                  NaN                NaN                  NaN                NaN                    NaN                   NaN                    NaN                NaN                     NaN               NaN                      NaN                        NaN                        NaN                  NaN                          NaN                       NaN                          NaN                        NaN                       NaN                     NaN                            NaN                             NaN                            NaN                       NaN                               NaN                          NaN                             NaN                               NaN                           NaN                                      NaN                                 NaN                                  NaN                              NaN                               NaN                NaN                        NaN                        NaN                        NaN                           NaN                                NaN                            NaN                       NaN                                NaN                    NaN                              NaN                           NaN                        NaN                             NaN                                  75.299117                 1
# 7  AGO002001  Benguela  Baia Farta              NaN               NaN             NaN               NaN             NaN                 NaN                NaN                 NaN             NaN                  NaN            NaN                   NaN                     NaN                     NaN               NaN                       NaN                    NaN                       NaN                     NaN                    NaN                  NaN                         NaN                          NaN                         NaN                    NaN                            NaN                       NaN                          NaN                            NaN                        NaN                                   NaN                              NaN                               NaN                           NaN                            NaN             NaN                   0.442                   0.258                   0.318                        NaN                             NaN                         NaN                    NaN                             NaN                 NaN                           NaN                        NaN                     NaN                          NaN                                     NaN                 NaN                  NaN                NaN                  NaN                NaN                    NaN                   NaN                    NaN                NaN                     NaN               NaN                      NaN                        NaN                        NaN                  NaN                          NaN                       NaN                          NaN                        NaN                       NaN                     NaN                            NaN                             NaN                            NaN                       NaN                               NaN                          NaN                             NaN                               NaN                           NaN                                      NaN                                 NaN                                  NaN                              NaN                               NaN                NaN                        NaN                        NaN                        NaN                           NaN                                NaN                            NaN                       NaN                                NaN                    NaN                              NaN                           NaN                        NaN                             NaN                                  75.299117                 1
# 8  AGO002001  Benguela  Baia Farta              NaN               NaN             NaN               NaN             NaN                 NaN                NaN                 NaN             NaN                  NaN            NaN                   NaN                     NaN                     NaN               NaN                       NaN                    NaN                       NaN                     NaN                    NaN                  NaN                         NaN                          NaN                         NaN                    NaN                            NaN                       NaN                          NaN                            NaN                        NaN                                   NaN                              NaN                               NaN                           NaN                            NaN             NaN                   0.442                   0.258                   0.318                        NaN                             NaN                         NaN                    NaN                             NaN                 NaN                           NaN                        NaN                     NaN                          NaN                                     NaN                 NaN                  NaN                NaN                  NaN                NaN                    NaN                   NaN                    NaN                NaN                     NaN               NaN                      NaN                        NaN                        NaN                  NaN                          NaN                       NaN                          NaN                        NaN                       NaN                     NaN                            NaN                             NaN                            NaN                       NaN                               NaN                          NaN                             NaN                               NaN                           NaN                                      NaN                                 NaN                                  NaN                              NaN                               NaN                NaN                        NaN                        NaN                        NaN                           NaN                                NaN                            NaN                       NaN                                NaN                    NaN                              NaN                           NaN                        NaN                             NaN                                  75.299117                 1
# 9  AGO002001  Benguela  Baia Farta              NaN               NaN             NaN               NaN             NaN                 NaN                NaN                 NaN             NaN                  NaN            NaN                   NaN                     NaN                     NaN               NaN                       NaN                    NaN                       NaN                     NaN                    NaN                  NaN                         NaN                          NaN                         NaN                    NaN                            NaN                       NaN                          NaN                            NaN                        NaN                                   NaN                              NaN                               NaN                           NaN                            NaN             NaN                   0.442                   0.258                   0.318                        NaN                             NaN                         NaN                    NaN                             NaN                 NaN                           NaN                        NaN                     NaN                          NaN                                     NaN                 NaN                  NaN                NaN                  NaN                NaN                    NaN                   NaN                    NaN                NaN                     NaN               NaN                      NaN                        NaN                        NaN                  NaN                          NaN                       NaN                          NaN                        NaN                       NaN                     NaN                            NaN                             NaN                            NaN                       NaN                               NaN                          NaN                             NaN                               NaN                           NaN                                      NaN                                 NaN                                  NaN                              NaN                               NaN                NaN                        NaN                        NaN                        NaN                           NaN                                NaN                            NaN                       NaN                                NaN                    NaN                              NaN                           NaN                        NaN                             NaN                                  75.299117                 1
#
# ================================================================================
# 7. POTENTIAL INSIGHTS
# ================================================================================
#   🔍 Columns with >50% missing data: poverty__rivers, poverty__streams, poverty__lakes, poverty__lagoons, poverty__wells, poverty__telephone, poverty__internet, poverty__newspaper, poverty__radio, poverty__television, poverty__none, poverty__electricity, poverty__water_storage, poverty__veterinarians, poverty__banking, poverty__mech_agri_equip, poverty__agri_schools, poverty__primary_schools, poverty__field_schools, poverty__health_units, poverty__agri_stock, poverty__went_without_food, poverty__unable_eat_healthy, poverty__few_types_of_food, poverty__skipped_meal, poverty__ate_less_than_needed, poverty__ran_out_of_food, poverty__hungry_did_not_eat, poverty__without_food_all_day, poverty__food_insec_scale, poverty__difficult_access_to_village, poverty__insufficient_transport, poverty__lack_conservation_infra, poverty__high_transport_cost, poverty__lack_transport_means, poverty__other, poverty__diff_access_land, poverty__unavailable_agri_land, poverty__diff_access_water, poverty__rural_exodus, poverty__diff_dispose_products, poverty__lack_rain, poverty__lack_agri_equipment, poverty__lack_tech_assist, poverty__lack_manpower, poverty__diff_access_credit, poverty__avg_hours_to_market_financial, traveltime__rivers, traveltime__streams, traveltime__lakes, traveltime__lagoons, traveltime__wells, traveltime__telephone, traveltime__internet, traveltime__newspaper, traveltime__radio, traveltime__television, traveltime__none, traveltime__electricity, traveltime__water_storage, traveltime__veterinarians, traveltime__banking, traveltime__mech_agri_equip, traveltime__agri_schools, traveltime__primary_schools, traveltime__field_schools, traveltime__health_units, traveltime__agri_stock, traveltime__went_without_food, traveltime__unable_eat_healthy, traveltime__few_types_of_food, traveltime__skipped_meal, traveltime__ate_less_than_needed, traveltime__ran_out_of_food, traveltime__hungry_did_not_eat, traveltime__without_food_all_day, traveltime__food_insec_scale, traveltime__difficult_access_to_village, traveltime__insufficient_transport, traveltime__lack_conservation_infra, traveltime__high_transport_cost, traveltime__lack_transport_means, traveltime__other, traveltime__poverty_rural, traveltime__poverty_urban, traveltime__poverty_total, traveltime__diff_access_land, traveltime__unavailable_agri_land, traveltime__diff_access_water, traveltime__rural_exodus, traveltime__diff_dispose_products, traveltime__lack_rain, traveltime__lack_agri_equipment, traveltime__lack_tech_assist, traveltime__lack_manpower, traveltime__diff_access_credit
#
# ================================================================================
# 8. SAVING OUTPUTS
# ================================================================================
#   ✅ JSON metadata saved: /mnt/c/Users/benny/OneDrive/Documents/Github/ago-lobitocorridor-analysis/outputs/analysis_summary/huambo_municipality_profiles_metadata.json
#   ✅ Text report saved: /mnt/c/Users/benny/OneDrive/Documents/Github/ago-lobitocorridor-analysis/outputs/analysis_summary/huambo_municipality_profiles_report.txt
#   ✅ Column list saved: /mnt/c/Users/benny/OneDrive/Documents/Github/ago-lobitocorridor-analysis/outputs/analysis_summary/huambo_municipality_profiles_columns.txt
#
# ================================================================================
# ✨ ANALYSIS COMPLETE!
# ================================================================================
#
# Output files saved to: /mnt/c/Users/benny/OneDrive/Documents/Github/ago-lobitocorridor-analysis/outputs/analysis_summary
#
# You can now share the generated files with Claude AI for further analysis!
